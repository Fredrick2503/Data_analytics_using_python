# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("btp-station-wise-accidents-2023.csv")
data
# Out:
#      Zone Sub-division          Station  2023 - Fatal Cases  \
# 0    East         East        Halasooru                  11
# 1    East         East      Indiranagar                  12
# 2    East         East   Pulikeshinagar                   4
# 3    East         East       Banasawadi                  14
# 4    East         East     Shivajinagar                   6
# ..    ...          ...              ...                 ...
# 58  South   HSR Layout  Electronic City                  38
# 59  South   HSR Layout       Bellanduru                   9
# 60    NaN   HSR Layout            Total                  63
# 61  South          NaN      South Total                 192
# 62  Total          NaN      Grand Total                 882
#
#     2023 - Killed People  2023 - Non-Fatal  2023 - Injured People  \
# 0                     11                56                     48
# 1                     12                73                     62
# ...

# %%
data.rename(columns={"2023 - Total Cases":"Total cases"},inplace=True)
data.drop(['Sub-division',"2023 - Fatal Cases","2023 - Killed People","2023 - Non-Fatal","2023 - Injured People"],axis=1,inplace=True)
totals_data=data[data["Station"].str.contains("Total")]
data=data[(data["Station"].str.contains("Total"))!=True]

# %%
print("Data after cleaning the data")
display(data)
# Out:
# Data after cleaning the data
#      Zone          Station  Total cases
# 0    East        Halasooru           67
# 1    East      Indiranagar           85
# 2    East   Pulikeshinagar           27
# 3    East       Banasawadi           91
# 4    East     Shivajinagar           27
# 5    East        K G Halli           40
# 7    East        K R Puram          254
# 8    East          Airport           97
# 9    East       Whitefield          223
# 10   East     Mahadevapura           93
# 13   West      Cubbon Park           56
# 14   West        H.Grounds           56
# 15   West        S.S.Nagar           47
# 16   West           U.Gate           54
# 17   West      Ashokanagar           38
# 18   West         W.Garden           65
# 20   West         Upparpet           29
# 21   West         Chickpet           46
# 22   West      City Market           32
# 23   West   Bytarayanapura          182
# 24   West          Kengeri          279
# 26   West      Vijayanagar           79
# ...

# %%
Zones=data["Zone"].drop_duplicates()
for zone in Zones:
    plt.figure(figsize=(16,9))
    ax=sns.barplot(data=data[data['Zone']==zone],x="Station",y="Total cases",width=0.3,palette="bright")
    ax.tick_params(axis='x',rotation=90)
    ax.tick_params(axis='both',labelsize=16)
    ax.xaxis.label.set_size(20)
    ax.yaxis.label.set_size(20)
    plt.axhline(y=(data[data['Zone']==zone])['Total cases'].mean(), color='black', linestyle='--', label='Average cases')
    plt.title(f"Bar graph visualising total cases in every station in {zone} zone",size=24)
    plt.show()
    display(data[data['Zone']==zone])
# Out:
# /tmp/ipykernel_4520/3080564170.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data=data[data['Zone']==zone],x="Station",y="Total cases",width=0.3,palette="bright")
#     Zone         Station  Total cases
# 0   East       Halasooru           67
# 1   East     Indiranagar           85
# 2   East  Pulikeshinagar           27
# 3   East      Banasawadi           91
# 4   East    Shivajinagar           27
# 5   East       K G Halli           40
# 7   East       K R Puram          254
# 8   East         Airport           97
# 9   East      Whitefield          223
# 10  East    Mahadevapura           93
# /tmp/ipykernel_4520/3080564170.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches
import seaborn as sns

# Data for the pie chart
Zones = data["Zone"].drop_duplicates()

for zone in Zones:
    plt.figure(figsize=(16, 9))
    zone_data = data[data['Zone'] == zone]
    stations = zone_data['Station']
    total_cases = zone_data['Total cases']
    
    # Generate a list of unique colors using the "bright" palette
    colors = sns.color_palette('bright', len(stations))
    
    # Plotting the pie chart
    wedges, texts = plt.pie(total_cases, colors=colors, startangle=140)
    
    # Adding a legend with station names and percentages
    legend_labels = [f'{station}: {percentage:.1f}%' for station, percentage in zip(stations, 100 * total_cases / total_cases.sum())]
    patches = [mpatches.Patch(facecolor=colors[i], label=legend_labels[i]) for i in range(len(stations))]
    plt.legend(handles=patches, title="Stations", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1), fontsize=16, title_fontsize=20)
    plt.title(f'Pie Chart of Total Cases in Every Station in {zone} Zone', size=24)
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    
    # Increase label size
    plt.setp(texts, size=16)
    
    plt.show()
    display(zone_data)
# Out:
#     Zone         Station  Total cases
# 0   East       Halasooru           67
# 1   East     Indiranagar           85
# 2   East  Pulikeshinagar           27
# 3   East      Banasawadi           91
# 4   East    Shivajinagar           27
# 5   East       K G Halli           40
# 7   East       K R Puram          254
# 8   East         Airport           97
# 9   East      Whitefield          223
# 10  East    Mahadevapura           93
#     Zone         Station  Total cases
# 13  West     Cubbon Park           56
# 14  West       H.Grounds           56
# 15  West       S.S.Nagar           47
# 16  West          U.Gate           54
# 17  West     Ashokanagar           38
# 18  West        W.Garden           65
# 20  West        Upparpet           29
# 21  West        Chickpet           46
# 22  West     City Market           32
# 23  West  Bytarayanapura          182
# 24  West         Kengeri          279
# 26  West     Vijayanagar           79
# 27  West     Magadi Road           50
# ...

# %%
cdata=(data[data.Zone.notnull()])

# %%
zonal_data=cdata[["Zone","Total cases"]].groupby("Zone").sum()
display(zonal_data)


plt.figure(figsize=(16,9))
sns.barplot(data=zonal_data,x=zonal_data.index,y="Total cases",palette="bright")
plt.title("Total cases in each zone",size=24)
plt.show()
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# Data for the pie chart
zones = zonal_data.index
total_cases = zonal_data['Total cases']

# Plotting the pie chart
plt.figure(figsize=(16, 9))
wedges, texts, autotexts = plt.pie(total_cases, startangle=140, autopct='%1.1f%%', colors=sns.color_palette('bright', len(zones)))

# Adding a legend with zone names and percentages
legend_labels = [f'{zone}: {percentage:.1f}%' for zone, percentage in zip(zones, 100 * total_cases / total_cases.sum())]
patches = [mpatches.Patch(facecolor=wedges[i].get_facecolor(), label=legend_labels[i]) for i in range(len(zones))]
plt.legend(handles=patches, title="Zones", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1), fontsize=16, title_fontsize=20)
plt.title('Pie Chart of Total Cases in Each Zone', size=24)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Increase font size of labels and text
plt.setp(autotexts, size=16)
plt.setp(texts, size=16)

plt.show()

plt.show()
# Out:
#        Total cases
# Zone
# East          1004
# North         1535
# South         1181
# West          1254
# /tmp/ipykernel_4520/943777236.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=zonal_data,x=zonal_data.index,y="Total cases",palette="bright")

# %%
plt.figure(figsize=(16,9))
ax=sns.barplot(data=cdata,x="Station",y="Total cases",width=0.3,label="total cases",palette="bright")
ax.tick_params(axis='x',rotation=90)
ax.tick_params(axis='both',labelsize=16)
ax.xaxis.label.set_size(20)
ax.yaxis.label.set_size(20)
plt.axhline(y=data['Total cases'].mean(), color='black', linestyle='--', label='Average cases')
plt.title("Bar graph visualising total cases in every station",size=24)
plt.show()
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# Data for the pie chart
stations = data['Station']
total_cases = data['Total cases']


# Plotting the pie chart
plt.figure(figsize=(20,20))
wedges, texts = plt.pie(total_cases, colors=colors, startangle=140)

# Adding IDs to the pie slices
for i, wedge in enumerate(wedges):
    angle = (wedge.theta2 - wedge.theta1) / 2.0 + wedge.theta1
    x = 0.9 * np.cos(np.radians(angle))  # Move the label a little further inside
    y = 0.9 * np.sin(np.radians(angle))  # Move the label a little further inside
    plt.text(x, y, str(i+1), ha='center', va='center', fontsize=20, transform=plt.gca().transData)

# Adding a legend with station names and IDs
legend_labels = [f'{i+1}. {station}: {percentage:.1f}%' for i, (station, percentage) in enumerate(zip(stations, 100 * total_cases / total_cases.sum()))]
patches = [mpatches.Patch(facecolor=colors[i], label=legend_labels[i]) for i in range(0,len(stations))]
plt.legend(handles=patches, title="Stations", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1), fontsize=20, title_fontsize=22)
plt.title('Pie Chart of Total Cases in Every Station')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# /tmp/ipykernel_4520/1136149119.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data=cdata,x="Station",y="Total cases",width=0.3,label="total cases",palette="bright")
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 32
#      30 # Adding a legend with station names and IDs
#      31 legend_labels = [f'{i+1}. {station}: {percentage:.1f}%' for i, (station, percentage) in enumerate(zip(stations, 100 * total_cases / total_cases.sum()))]
# ---> 32 patches = [mpatches.Patch(facecolor=colors[i], label=legend_labels[i]) for i in range(0,len(stations))]
#      33 plt.legend(handles=patches, title="Stations", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1), fontsize=20, title_fontsize=22)
# ...

# %%
avg_cases=(4974/cdata.Station.count())
print("Stations having more than averge cases")
data_above_avg=cdata[cdata["Total cases"]>avg_cases].sort_values("Total cases",ascending=False)
plt.figure(figsize=(16,9))
ax=sns.barplot(data=data_above_avg,x="Station",y="Total cases",width=0.3,label="total cases",palette="bright")
ax.tick_params(axis='x',rotation=90)
ax.tick_params(axis='both',labelsize=16)
ax.xaxis.label.set_size(20)
ax.yaxis.label.set_size(20)
plt.title("Bar graph visualising total cases in every station",size=24)
plt.show()
# Out:
# Stations having more than averge cases
